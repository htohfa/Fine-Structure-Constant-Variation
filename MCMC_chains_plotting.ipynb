# %%
import numpy as np
import tempfile, os
tempdir = '../bmbfq/'
rootname = os.path.join(tempdir, 'test')
from getdist import loadMCSamples,paramnames
from getdist import plots, gaussian_mixtures,MCSamples

#print(filename)
#paramnames.ParamList(fileName=filename)
epsilon=0.3
samples = loadMCSamples(rootname,settings={'ignore_rows':epsilon})


ndim=3
# Out:
# ../bmbfq/test_29.txt
# ../bmbfq/test_15.txt
# ../bmbfq/test_14.txt
# ../bmbfq/test_28.txt
# ../bmbfq/test_16.txt
# ../bmbfq/test_8.txt
# ../bmbfq/test_9.txt
# ../bmbfq/test_17.txt
# ../bmbfq/test_13.txt
# ../bmbfq/test_12.txt
# ../bmbfq/test_10.txt
# ../bmbfq/test_11.txt
# ../bmbfq/test_20.txt
# ../bmbfq/test_2.txt
# ../bmbfq/test_3.txt
# ../bmbfq/test_21.txt
# ../bmbfq/test_23.txt
# ../bmbfq/test_1.txt
# ../bmbfq/test_22.txt
# ../bmbfq/test_26.txt
# ../bmbfq/test_32.txt
# ../bmbfq/test_4.txt
# ../bmbfq/test_5.txt
# ../bmbfq/test_27.txt
# ../bmbfq/test_31.txt
# ../bmbfq/test_25.txt
# ../bmbfq/test_19.txt
# ../bmbfq/test_7.txt
# ../bmbfq/test_6.txt
# ../bmbfq/test_18.txt
# ../bmbfq/test_24.txt
# ../bmbfq/test_30.txt
# Removed 0.3 as burn in

# %%
import numpy as np
import tempfile, os
tempdir = '../QSO/'
rootname = os.path.join(tempdir, 'test')
from getdist import loadMCSamples,paramnames
from getdist import plots, gaussian_mixtures,MCSamples

#print(filename)
#paramnames.ParamList(fileName=filename)
epsilon=0.3
samples2 = loadMCSamples(rootname,settings={'ignore_rows':epsilon})


ndim=4

# %%
g = plots.get_subplot_plotter(width_inch = 10)

g.triangle_plot(samples, ['bm','bf','phi_1'],filled=True)
# Out:
# WARNING:root:auto bandwidth for bm very small or failed (h=0.00019361968781745814,N_eff=1303.850467294881). Using fallback (h=0.00036249984650159263)
# WARNING:root:fine_bins not large enough to well sample smoothing scale - bm

# %%
g = plots.get_subplot_plotter(width_inch = 10)

g.triangle_plot([samples,samples2], ['a','bf','c','phi_0'],filled=True)
g.add_legend(['QSO', 'CMB'], colored_text=True);
# Out:
# WARNING:root:auto bandwidth for bf very small or failed (h=0.0010309106169003356,N_eff=6402.725747785661). Using fallback (h=0.041455284159396005)
# WARNING:root:auto bandwidth for c very small or failed (h=0.0006636371232321707,N_eff=5543.4404809929765). Using fallback (h=0.002086229318575942)

# %%
g = plots.get_subplot_plotter(width_inch = 4)
g.plot_2d([samples], 'a', 'bf',filled="True")
# Out:
# ((-10.0, 10.0), (-5.0, 5.0))

# %%
g = plots.get_single_plotter(width_inch=4)
g.plot_1d(samples, 'm', marker=0)

# %%
g = plots.get_single_plotter(width_inch=4)
g.plot_1d(samples, 'zeta', marker=0)

# %%
g = plots.get_subplot_plotter(width_inch = 10)

g.triangle_plot(samples, ['zeta', 'm'],filled=True)

# %%
import numpy
numpy.exp(-1e6)
# Out:
# 0.0
